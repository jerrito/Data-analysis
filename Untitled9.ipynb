# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
table=pd.read_csv("TIMETABLE.CSV")
table.head(30)
# Out:
#     IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0          3997    ENG105B         NaN        46.0           145       100
# 1          3998    ENG105B         NaN        14.0           140       100
# 2          3999    ENG105B         NaN        34.0           140       100
# 3          4000    ENG105B         NaN        35.0           140       100
# 4          4001    ENG105B         NaN        10.0           130       100
# 5          4002    ENG105B         NaN        11.0           120       100
# 6          4003    ENG105B         NaN        12.0           120       100
# 7          4004    ENG105B         NaN        13.0           120       100
# 8          4005    ENG105B         NaN        45.0           120       100
# 9          4006    ENG105B         NaN        18.0           115       100
# 10         4007    ENG105B         NaN         3.0           115       100
# ...

# %%
table["examDATE"]=pd.to_datetime(table["examDATE"])
table.info()
table.describe(include="all")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 775 entries, 0 to 774
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IDtimetable   775 non-null    int64
#  1   coursecode    775 non-null    object
#  2   IDprogramme   649 non-null    object
#  3   coursegrps    59 non-null     float64
#  4   numbstudents  775 non-null    int64
#  5   stdlevel      775 non-null    int64
#  6   IDroom        775 non-null    int64
#  7   roomname      775 non-null    object
#  8   examPERIOD    775 non-null    object
#  9   examDATE      775 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(4), object(4)
# memory usage: 60.7+ KB
# ...

# %%
t1=(table.loc[:,["IDtimetable", "coursecode","numbstudents"]])
t1.sort_values(by="coursecode",  ascending=True)
# Out:
#      IDtimetable coursecode  numbstudents
# 380         4753    AAS201N           108
# 235         4325    AAS304N           102
# 334         4707    AAS305N           102
# 286         4456    AAS401N            26
# 258         4428    AAS404N            25
# ..           ...        ...           ...
# 363         4736     THS425             2
# 625         4512     THS428            15
# 366         4739     THS429             1
# 394         4767     TMG399            56
# 288         4458     TMG406            44
#
# [775 rows x 3 columns]

# %%
table.groupby( ["coursecode"],sort="False")["numbstudents"].agg("mean")
# Out:
# coursecode
# AAS201N    108.0
# AAS304N    102.0
# AAS305N    102.0
# AAS401N     26.0
# AAS404N     25.0
#            ...
# THS425       2.0
# THS428      15.0
# THS429       1.0
# TMG399      56.0
# TMG406      44.0
# Name: numbstudents, Length: 633, dtype: float64

# %%
(table.loc[:,"coursecode"]).head(70)
# Out:
# 0     ENG105B
# 1     ENG105B
# 2     ENG105B
# 3     ENG105B
# 4     ENG105B
#        ...
# 65     ILT101
# 66     ILT101
# 67     ILT101
# 68     ILT101
# 69     ILT101
# Name: coursecode, Length: 70, dtype: object

# %%
AX=pd.DataFrame({
    "A":["foo", "bar", "foo", "bar", "foo", "bar"],
    "B":["one","two", "three","one","three","two"],
    "C":np.random.randn(6),
    "D":np.random.randn(6)
})
AX
# Out:
#      A      B         C         D
# 0  foo    one  0.485519 -0.738991
# 1  bar    two -0.632599  2.211352
# 2  foo  three -1.486241 -0.466861
# 3  bar    one -0.652806  0.029933
# 4  foo  three -0.175775 -0.643876
# 5  bar    two  1.174506  1.371403

# %%
AX.set_index(["A","B"])
# Out:
#                   C         D
# A   B
# foo one    0.485519 -0.738991
# bar two   -0.632599  2.211352
# foo three -1.486241 -0.466861
# bar one   -0.652806  0.029933
# foo three -0.175775 -0.643876
# bar two    1.174506  1.371403
