# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline

# %%
her=pd.Series([2,4,6,8], name="Num")
print(type(her))
print(plt.plot(her))
print(plt.boxplot(her))
plt.pie(her,labels=['a','b','c','d'])
# Out:
# <class 'pandas.core.series.Series'>
# ...
# {'whiskers': [<matplotlib.lines.Line2D object at 0x000001C606012B50>, <matplotlib.lines.Line2D object at 0x000001C606012EB0>], 'caps': [<matplotlib.lines.Line2D object at 0x000001C6060124F0>, <matplotlib.lines.Line2D object at 0x000001C606012760>], 'boxes': [<matplotlib.lines.Line2D object at 0x000001C60602AB20>], 'medians': [<matplotlib.lines.Line2D object at 0x000001C605FFA700>], 'fliers': [<matplotlib.lines.Line2D object at 0x000001C605FFA400>], 'means': []}
# ([<matplotlib.patches.Wedge at 0x1c60602a640>,
# ...
#  [Text(1.0461621663333946, 0.3399186987098808, 'a'),
#   Text(0.33991867422268784, 1.0461621742897658, 'b'),
#   Text(-1.0461621902025062, 0.3399186252483017, 'c'),
#   Text(0.3399188211458418, -1.0461621265515308, 'd')])

# %%
A=np.random.randint(1,100,5)
B=np.random.randint(1,100,5)
C=np.random.randint(1,100,5)
D=np.random.randint(1,100,5)
E=np.random.randint(1,100,5)
data_frame=pd.DataFrame(data=[A,B,C,D,E],columns=["A","B","C","D","E"])
data_frame
F=np.where(data_frame["E"]>32, "Male","Female")
data_frame["F"]=F
data_frame
# Out:
#     A   B   C   D   E       F
# 0  64  98  33  53  81    Male
# 1  50  88  36  79  55    Male
# 2   6  63  72  53  33    Male
# 3   7  98  97  43   3  Female
# 4  85  30  26  73  26  Female

# %%
titanic=pd.read_csv("titanic.csv")
titanic.head(20)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-bd5c8e4a18c1> in <module>
# ----> 1 titanic=pd.read_csv("titanic.csv")
#       2 titanic.head(20)
#       3
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
# ...

# %%
titanic.describe
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
print(titanic.columns)

Known_age=titanic[titanic.loc[:,['PassengerId','Pclass','Cabin']].notna()]
Known_age.loc[:,['PassengerId','Pclass','Cabin']].head(15)
titanic.loc[:1,["Cabin"]]="C12"
#Known_age.loc[:,['PassengerId','Pclass','Cabin']]
titanic
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# ...

# %%
titanic.plot.scatter(x="PassengerId",y="Age" )
# Out:
# <AxesSubplot:xlabel='PassengerId', ylabel='Age'>

# %%
 df = pd.DataFrame(
 {
 "x": np.random.randint(1.0, 168.0, 12),
 "y": np.random.randint(1.0, 100, 12),
 "z": np.random.randint(1.7, 130, 12),
  #"week": [1,2,3] * 4,
 },
 index =pd.date_range("2021-08-01",periods=12,freq="D")
 )
df
# Out:
#               x   y    z
# 2021-08-01   70  12    7
# 2021-08-02    9  32   36
# 2021-08-03   47  44   54
# 2021-08-04  144  71   89
# 2021-08-05  142  47   29
# 2021-08-06   25  59   81
# 2021-08-07  156  16   45
# 2021-08-08  110  69  121
# 2021-08-09  107  36  114
# 2021-08-10  160  28   53
# 2021-08-11  111   9   50
# 2021-08-12  155  98   18

# %%
df2 =pd.DataFrame(columns=["u","v","w"],
                  data=(np.random.randn(12,3)+30),
         index=pd.date_range("2021-07-19", periods=12, freq="D"))
df2
# Out:
#                     u          v          w
# 2021-07-19  29.011862  29.075240  29.402994
# 2021-07-20  30.521098  30.498657  30.915568
# 2021-07-21  28.463462  29.354699  31.513790
# 2021-07-22  29.343090  30.185891  30.714408
# 2021-07-23  29.804236  29.422678  30.071860
# 2021-07-24  29.711761  31.046522  28.982253
# 2021-07-25  31.544064  30.858484  29.681862
# 2021-07-26  30.006342  29.963444  31.738120
# 2021-07-27  29.890376  28.599037  30.760539
# 2021-07-28  29.005913  30.994393  30.829487
# 2021-07-29  30.507508  29.341295  30.573985
# 2021-07-30  29.268563  29.925676  29.675904

# %%
merged=[df,df2]
pd.concat(merged)
# Out:
#                 x     y      z          u          v          w
# 2021-08-01   70.0  12.0    7.0        NaN        NaN        NaN
# 2021-08-02    9.0  32.0   36.0        NaN        NaN        NaN
# 2021-08-03   47.0  44.0   54.0        NaN        NaN        NaN
# 2021-08-04  144.0  71.0   89.0        NaN        NaN        NaN
# 2021-08-05  142.0  47.0   29.0        NaN        NaN        NaN
# 2021-08-06   25.0  59.0   81.0        NaN        NaN        NaN
# 2021-08-07  156.0  16.0   45.0        NaN        NaN        NaN
# 2021-08-08  110.0  69.0  121.0        NaN        NaN        NaN
# 2021-08-09  107.0  36.0  114.0        NaN        NaN        NaN
# 2021-08-10  160.0  28.0   53.0        NaN        NaN        NaN
# 2021-08-11  111.0   9.0   50.0        NaN        NaN        NaN
# 2021-08-12  155.0  98.0   18.0        NaN        NaN        NaN
# 2021-07-19    NaN   NaN    NaN  29.011862  29.075240  29.402994
# 2021-07-20    NaN   NaN    NaN  30.521098  30.498657  30.915568
# ...

# %%
 mdf = pd.melt(df, id_vars=["month", "week"])
    
 pd.pivot_table(
 mdf,
 values="value",
 index=["variable", "week"],
 columns=["month"],
 aggfunc=np.mean,
 )
# Out:
# month                   5           6           7
# variable week
# x        1      85.148980  104.963957   86.515918
#          2     123.334164   28.261821  109.409401
# y        1      44.500000   65.000000   44.500000
#          2      70.500000   60.000000   29.500000
# z        1      17.709829   14.597757   12.431410
#          2      13.848836   15.219084   13.524584
