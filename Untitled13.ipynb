# %%
import pandas as pd 
import numpy as np

# %%
Data=pd.read_excel("./Book1_050613.xlsx")

Data.rename(columns=Data.loc[0])
# Out:
#     Second trimester Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0                BPD         HC         AC         FL        TCD        LMP
# 1             20w 2d     21w 1d     22w 0d     20w 5d     20w 4d      20w 4
# 2             25w 3d     24w 1d     27w 2d     26w 1d     26w 2d     26w 2d
# 3             19w 1d     20w 2d     21w 1d     20w 5d     20w 4d     20w 4d
# 4             24w 2d     26w 1d     27w 1d     25w 6d     26w 1d     26w 0d
# ..               ...        ...        ...        ...        ...        ...
# 107           30w 2d     29w 4d     30w 5d     30w 0d     30w 2d     30w 0d
# 108           30w 5d     31w 0d     32w 0d     31w 3d     31w 5d     31w 5d
# 109           34w 4d     34w 5d     35w 3d     34w 6d     35w 0d     35w 0d
# 110           33w 2d     34w 0d     33w 0d     33w 5d     32w 2d     332 0d
# 111           30w 2d     29w 4d     30w 5d     30w 0d     30w 2d     30w 0d
#
# [112 rows x 6 columns]

# %%
Data.columns
# Out:
# Index(['Second trimester', 'Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3',
#        'Unnamed: 4', 'Unnamed: 5'],
#       dtype='object')

# %%
Data.rename(columns=Data.loc[0],inplace=True)
Priscilla=Data.loc[1:,]

# %%
Main=Priscilla.loc[1:45,]

# %%
name="Second Trimester.csv"
Main.to_csv(name)

# %%
Main
# Out:
#         BPD      HC      AC       FL      TCD     LMP
# 1    20w 2d  21w 1d  22w 0d   20w 5d   20w 4d   20w 4
# 2    25w 3d  24w 1d  27w 2d   26w 1d   26w 2d  26w 2d
# 3    19w 1d  20w 2d  21w 1d   20w 5d   20w 4d  20w 4d
# 4    24w 2d  26w 1d  27w 1d   25w 6d   26w 1d  26w 0d
# 5    18w 2d  19w 1d  19w 6d   20w 1d   19w 1d  19w 3d
# 6    21w 1d  22w 1d  22w 0d   21w 5d   21w 5d  22w 0d
# 7    27w 1d  28w 2d  28w 3d   26w 4d   27w 1d  27w 0d
# 8    23w 4d  22w 1d  23w 6d   23w 0d   22w 5d  23w 0d
# 9    24w 3d  25w 1d  25w 6d   24w 6d   24w 0d  24w 0d
# 10   22w 4d  22w 6d  21w 5d   20w 5d   21w 6d  21w 6d
# 11   19w 2d  18w 3d  21w 0d   20w 4d   19w 3d  19w 3d
# 12   27w 1d  26w 4d  28w 0d   28w 1d   26w 1d  26w 0d
# 13   23w 1d  22w 5d  22w 5d   23w 4d   23w 0d  23w 0d
# 14   20w 4d  20w 5d  20w 3d   21w 2d   21w 2d  20w 0d
# 15   25w 2d  25w 5d  25w 1d   25w 4d   25w 0d  25w 0d
# 16   23w 2d  23w 0d  23w 1d   24w 2d   24w 2d  24w 2d
# ...
