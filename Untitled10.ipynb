# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
T=pd.read_csv("TIMETABLE.csv")
T
# Out:
#      IDtimetable coursecode           IDprogramme  coursegrps  numbstudents  \
# 0           3997    ENG105B                   NaN        46.0           145
# 1           3998    ENG105B                   NaN        14.0           140
# 2           3999    ENG105B                   NaN        34.0           140
# 3           4000    ENG105B                   NaN        35.0           140
# 4           4001    ENG105B                   NaN        10.0           130
# ..           ...        ...                   ...         ...           ...
# 770         4657     INF306    BSC ( INFO. TECH.)         NaN            32
# 771         4658     ESC399     B. ED. ( SCIENCE)         NaN            40
# 772         4659     MUD314     BACHELOR OF MUSIC         NaN             1
# 773         4660     EBS214  B. ED. ( BASIC. ED.)         NaN            16
# 774         4661     MLT215        BSC. ( MEDLAB)         NaN            63
#
# ...

# %%
T.loc[:,["coursecode","numbstudents"]]
# Out:
#     coursecode  numbstudents
# 0      ENG105B           145
# 1      ENG105B           140
# 2      ENG105B           140
# 3      ENG105B           140
# 4      ENG105B           130
# ..         ...           ...
# 770     INF306            32
# 771     ESC399            40
# 772     MUD314             1
# 773     EBS214            16
# 774     MLT215            63
#
# [775 rows x 2 columns]

# %%
T.fillna(value=0)
# Out:
#      IDtimetable coursecode           IDprogramme  coursegrps  numbstudents  \
# 0           3997    ENG105B                     0        46.0           145
# 1           3998    ENG105B                     0        14.0           140
# 2           3999    ENG105B                     0        34.0           140
# 3           4000    ENG105B                     0        35.0           140
# 4           4001    ENG105B                     0        10.0           130
# ..           ...        ...                   ...         ...           ...
# 770         4657     INF306    BSC ( INFO. TECH.)         0.0            32
# 771         4658     ESC399     B. ED. ( SCIENCE)         0.0            40
# 772         4659     MUD314     BACHELOR OF MUSIC         0.0             1
# 773         4660     EBS214  B. ED. ( BASIC. ED.)         0.0            16
# 774         4661     MLT215        BSC. ( MEDLAB)         0.0            63
#
# ...

# %%
T1=T.loc[T["numbstudents"]==16]
T1
# Out:
#      IDtimetable coursecode                   IDprogramme  coursegrps  \
# 49          4095     HIV101               B. ED. ( MATHS)         NaN
# 79          4125     ILT101  BSC. ( WATER AND SANITATION)         NaN
# 137         4227     THS312        B. A. ( THEATRE STDS.)         NaN
# 148         4238     THS318        B. A. ( THEATRE STDS.)         NaN
# 253         4423     POH422          BA ( POP. & HEALTH.)         NaN
# 318         4691     ECO310      B. A. ( SOCIAL SCIENCES)         NaN
# 346         4719     FRE412                 B. A. ( ARTS)         NaN
# 354         4727     CTN410   BSC ( INDUSTRIAL CHEMISTRY)         NaN
# 386         4759    GHL316A                 B. A. ( ARTS)         NaN
# 519         4410     CTN411   BSC ( INDUSTRIAL CHEMISTRY)         NaN
# 577         4464     CTN408   BSC ( INDUSTRIAL CHEMISTRY)         NaN
# 583         4470     EAS403                B. ED. ( ARTS)         NaN
# ...

# %%
T[T["coursecode"]=="ENG105B"]
# Out:
#      IDtimetable coursecode IDprogramme  coursegrps  numbstudents  stdlevel  \
# 0           3997    ENG105B         NaN        46.0           145       100
# 1           3998    ENG105B         NaN        14.0           140       100
# 2           3999    ENG105B         NaN        34.0           140       100
# 3           4000    ENG105B         NaN        35.0           140       100
# 4           4001    ENG105B         NaN        10.0           130       100
# 5           4002    ENG105B         NaN        11.0           120       100
# 6           4003    ENG105B         NaN        12.0           120       100
# 7           4004    ENG105B         NaN        13.0           120       100
# 8           4005    ENG105B         NaN        45.0           120       100
# 9           4006    ENG105B         NaN        18.0           115       100
# 10          4007    ENG105B         NaN         3.0           115       100
# ...

# %%
T.groupby(["coursecode", "numbstudents","IDtimetable",]).agg("numbstudents").sum()
# Out:
# coursecode  numbstudents  IDtimetable
# AAS201N     108           4753           108
# AAS304N     102           4325           102
# AAS305N     102           4707           102
# AAS401N     26            4456            26
# AAS404N     25            4428            25
#                                         ...
# THS425      2             4736             2
# THS428      15            4512            15
# THS429      1             4739             1
# TMG399      56            4767            56
# TMG406      44            4458            44
# Name: numbstudents, Length: 775, dtype: int64
